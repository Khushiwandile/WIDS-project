# %%
# !pip install yfinance
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta


stocks = ['AAPL', 'GOOGL', 'MSFT', 'AMZN']


end_date = datetime.now()
start_date = end_date - timedelta(days=5 * 365)


for stock_symbol in stocks:
    
    stock_df = yf.download(stock_symbol, start=start_date, end=end_date, progress=False)
    
    
    print(f"\n{stock_symbol} Data:")
    print(stock_df.head())
    
    
    file_path = f'C:/Users/HP/Desktop/WiDS LSTM/{stock_symbol.lower()}_data.csv'
    stock_df.to_csv(file_path, index=True)
    
    print(f"{stock_symbol} data saved to {file_path}\n")
# Out:
# ...
#
# AAPL Data:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2018-12-31  39.632500  39.840000  39.119999  39.435001  37.850147  140014000
# 2019-01-02  38.722500  39.712502  38.557499  39.480000  37.893326  148158800
# 2019-01-03  35.994999  36.430000  35.500000  35.547501  34.118881  365248800
# 2019-01-04  36.132500  37.137501  35.950001  37.064999  35.575382  234428400
# 2019-01-07  37.174999  37.207500  36.474998  36.982498  35.496204  219111200
# AAPL data saved to C:/Users/HP/Desktop/WiDS LSTM/aapl_data.csv
#
#
# GOOGL Data:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2018-12-31  52.891499  53.149502  51.652000  52.248001  52.248001  33110000
# 2019-01-02  51.360001  53.039501  51.264000  52.734001  52.734001  31868000
# 2019-01-03  52.533501  53.313000  51.118500  51.273499  51.273499  41960000
# 2019-01-04  52.127998  54.000000  51.842999  53.903500  53.903500  46022000
# ...
